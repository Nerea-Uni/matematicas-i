# %% [markdown]
# $$
# \def\CC{\bf C}
# \def\QQ{\bf Q}
# \def\RR{\bf R}
# \def\ZZ{\bf Z}
# \def\NN{\bf N}
# $$
# # Práctica 1. Hoja de Trabajo
#
# ## Resolver los siguientes ejercicios:
#
# Ejercicio 1. Resolver la siguiente ecuación y comprobarla gráficamente: $2x(x^2-6)=x^2(x-1)-6x$.
#
# Ejercicio 2. Comprobar gráficamente si es cierta o no la siguiente afirmación: "existe un número $r>0$ tal que $x < \operatorname{sen}\dfrac{1}{x}$ para todo $x\in (0,r)$".
#
# Ejercicio 3. Resolver Y comprobar gráficamente:
#
# 1.  $\dfrac{2x^2+9x+6}{x+2}\geq 1$.
# 2.  $|x^2-5x+6|=-(x^2-5x+6)$.
#
# Ejercicio 4. Hallar los $x$ que verifican las dos desigualdades siguientes $\frac{x}{|x-1|}\geq 0$, $\frac{1}{x}<x+1$.

# %% [markdown]
# _Ejercicio 1

# %%
f(x)=(2*x*((x^2)-6)==(x^2)*(x-1)-6*x)
solve (f(x),x)
# Out:
# [x == -3, x == 2, x == 0]

# %%
f(x)=(2*x*((x^2)-6)==(x^2)*(x-1)-6*x)
solve (f(x),x)
plot(f(x),(x,-3,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Ejercicio 2

# %%
f(x)=sin(1/x)-x
plot(f(x),(x,0,0.5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Ejercicio 3.1

# %%
desig=solve((2*(x^2)+(9*x)+6)/(x+2)>=1,x,to_poly_solve=True)
show(desig)
# Out:
# [[x >= -sqrt(2) - 2, x < -2], [x >= sqrt(2) - 2]]

# %%
d(x)=(2*x^2+9*x+6)/(x+2)-1
plot(d(x),(x,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Ejercicio 3.2

# %%
desig=solve(abs(x^2-5*x+6)==-(x^2-5*x+6),x,to_poly_solve=True) 
show(desigual)

# %%
d(x)=abs(((x^2)-(5*x)+6)+((x^2)-(5*x)+6))
plot(d(x),(x,-3,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Ejercicio 4

# %%
desig=solve((x/abs(x-1)),x,to_poly_solve=True) 
show(desig)
# Out:
# [x == 0]

# %%
desig=solve((1/x)<(x+1),x,to_poly_solve=True) 
show(desig)
# Out:
# [[x > -1/2*sqrt(5) - 1/2, x < 0], [x > 1/2*sqrt(5) - 1/2]]
