# %% [markdown]
# $$
# \def\CC{\bf C}
# \def\QQ{\bf Q}
# \def\RR{\bf R}
# \def\ZZ{\bf Z}
# \def\NN{\bf N}
# $$
#
# # Hoja de trabajo 4.

# %% [markdown]
# **Ejercicio 1.** Sean las funciones $\displaystyle f(x)=\log\left(x^2-\frac52 x +1\right)$ y $g(x)=f(x)+f(-x)$. Hallar los dominios de $f$ y $g$, dibujar sus gráficas y hallar sus puntos de corte con el eje OX.

# %%
reset()
f(x)=log(x^2-(5/2)*x+1)
show(f(x))
plot (f(x))
# Out:
# log(x^2 - 5/2*x + 1)
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 50 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'can't convert complex to float'
# Graphics object consisting of 1 graphics primitive

# %%
g(x)=f(x)+f(-x)
show(g(x))
plot(f(x))
# Out:
# log(x^2 + 5/2*x + 1) + log(x^2 - 5/2*x + 1)
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 51 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'can't convert complex to float'
# Graphics object consisting of 1 graphics primitive

# %%
x1=find_root(f(x),-0.1,0.1)
show([x1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-69a31b620971> in <module>()
# ----> 1 x1=find_root(f(x),-RealNumber('0.1'),RealNumber('0.1'))
#       2 show([x1])
#
# NameError: name 'f' is not defined

# %%
x2=find_root((f(x)+f(-x)),-0.1,0.1)
show([x2])
# Out:
# [0.009999999999992668]

# %% [markdown]
# **Ejercicio 2.** Sea $\displaystyle f(x)=\log\left(\sqrt{\frac{1-\cos x}{1+\cos x}}\right)$. Probar que $\displaystyle f'(x)=\frac{1}{\operatorname{sen} x}$.

# %%
reset()
f(x)=log(sqrt((1-cos(x))/(1+cos(x))))
show(f(x))
# Out:
# log(sqrt(-(cos(x) - 1)/(cos(x) + 1)))

# %%
fprima(x)=diff(f(x),x).full_simplify()
show(fprima(x))
# Out:
# 1/sin(x)

# %% [markdown]
# **Ejercicio 3.** Sea la función $\displaystyle f(x)=\operatorname{arctan} x-\operatorname{arccos} \frac{1}{\sqrt{1+x^2}}$. Demostrar que $f$ es constante en $(0,+\infty)$ viendo que la derivada es $0$ allí. ¿Qué constante es? Haz una gráfica para verificarlo. Comprueba si Sage sabe ver directamente que $f(x)$ es constante.

# %%
reset()
f(x)=arctan(x)-arccos(1/sqrt(1+x^2))
fprima(x)=diff(f(x),x)
show(f(x))
plot(f(x),x,0,6)
# Out:
# -arccos(1/sqrt(x^2 + 1)) + arctan(x)
# Graphics object consisting of 1 graphics primitive

# %%
show(f(2.0))
show(f(3.))
show(f(15.))
# Out:
# 0.000000000000000
# 0.000000000000000
# 0.000000000000000

# %%
plot(fprima(x),x,0,6,ymax=6)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# **Ejercicio 4.** Considera la función $f(x) = \dfrac{10000x^4-40001x^2+4}{10000(x^4+1)}$.
# - Dibuja su gráfica en el intervalo [-4,4]
# - Hallar el límite de $f(x)$ cuando $x \to +\infty$ y cuando $x \to -\infty$ y los puntos de corte con los ejes.
# - Hallar sus máximos y mínimos (relativos y absolutos) en $\mathbb{R}$.
# - Halla sus puntos de inflexión usando el comando find_root.

# %%
reset()
f(x)= (10000*x^4-40001*x^2+4)/(10000*(x^4+1))
show(f(x))
f1(x)=diff(f(x),x)
f2(x)=diff(f(x),x,x)
(solve(f1(x)==0,x))
# Out:
# 1/10000*(10000*x^4 - 40001*x^2 + 4)/(x^4 + 1)
# [x == -sqrt(1/2353*sqrt(5882353) - 588/2353), x == sqrt(1/2353*sqrt(5882353) - 588/2353), x == -sqrt(-1/2353*sqrt(5882353) - 588/2353), x == sqrt(-1/2353*sqrt(5882353) - 588/2353), x == 0]

# %%
show((-sqrt(1/2353*sqrt(5882353)) - 588/2353).n())
show((sqrt(1/2353*sqrt(5882353)) - 588/2353).n())
show((-sqrt(-1/2353*sqrt(5882353)) - 588/2353).n())
show((sqrt(-1/2353*sqrt(5882353)) - 588/2353).n())
# Out:
# -1.26515265697184
# 0.765365151659473
# -0.249893752656184 - 1.01525890431566*I
# -0.249893752656184 + 1.01525890431566*I

# %%
plot(f2(x),x,-4,4,figsize=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x1=find_root((10000*x^4-40001*x^2+4)/(10000*(x^4+1))-x,-2,-1/2)
x2=find_root((10000*x^4-40001*x^2+4)/(10000*(x^4+1))-x,-1/2,0)
x3=find_root((10000*x^4-40001*x^2+4)/(10000*(x^4+1))-x,0,1/2)
x4=find_root((10000*x^4-40001*x^2+4)/(10000*(x^4+1))-x,1/2,2)
show([x1,x2,x3,x4])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>()
#       2 x2=find_root((Integer(10000)*x**Integer(4)-Integer(40001)*x**Integer(2)+Integer(4))/(Integer(10000)*(x**Integer(4)+Integer(1)))-x,-Integer(1)/Integer(2),Integer(0))
#       3 x3=find_root((Integer(10000)*x**Integer(4)-Integer(40001)*x**Integer(2)+Integer(4))/(Integer(10000)*(x**Integer(4)+Integer(1)))-x,Integer(0),Integer(1)/Integer(2))
# ----> 4 x4=find_root((Integer(10000)*x**Integer(4)-Integer(40001)*x**Integer(2)+Integer(4))/(Integer(10000)*(x**Integer(4)+Integer(1)))-x,Integer(1),Integer(2))
#       5 show([x1,x2,x3,x4])
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/misc/lazy_import.pyx in sage.misc.lazy_import.LazyImport.__call__ (build/cythonized/sage/misc/lazy_import.c:3686)()
#     351             True
# ...

# %% [markdown]
# **Ejercicio 5.** Hallar los máximos y mínimos relativos y absolutos de la función $f(x) = (8x^2-9) e^{x^2}$ en el intervalo $[-2,1.5]$. Dibujar la gráfica de la función en todo el intervalo $[-2,1.5]$. Dibujar la gráfica de la función en intervalos más pequeños, de modo que se vean los máximos y mínimos.

# %%
reset()
f(x)=(8*(x^2)-9)*(e^(x^2))
show(f(x))
plot(f(x),x,-2,1.5)
# Out:
# (8*x^2 - 9)*e^(x^2)
# Graphics object consisting of 1 graphics primitive

# %%
plot(f(x),x,-0.5,0.5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(x)=diff(f(x),x)
f2(x)=diff(f(x),x,x)
solve(f1(x)==0,x)
# Out:
# [x == -1/4*sqrt(2), x == 1/4*sqrt(2), x == 0]

# %%
#Mínimo relativo en x=-0.3 y x= 0.3 (valores aproximados)
#Máximo relativo en x=0

# %% [markdown]
# **Ejercicio 6.** El polinomio $p (x) = x^4 - 6x^2 + x + 5$ tiene cuatro raíces reales. Dibujarlo comprobar que con $x_0=-1$ el método de Newton converge a la raíz más cerca de $-1$. Comparar el resultado hallando la solución cerca de $-1$ con find\_root.

# %%
#No hemos llegado a dar el método de Newton en las clases de teoría.
